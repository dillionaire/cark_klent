# %%
import pandas as pd
import missingno as no

# %%
df = pd.read_csv('201709-CAH_PulseOfTheNation_Raw.csv')

# %%
no.matrix(df)

# %%
no.bar(df)

# %%
pp.ProfileReport(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c5473803fb1b> in <module>
# ----> 1 pandas_profiling.ProfileReport(df)
#
# NameError: name 'pandas_profiling' is not defined
